# %%
import pandas as pd

# %%
airlines_df = pd.read_csv("data/Airline ID to Name.csv")

# %%
flight_bookings_df = pd.read_csv("data/Flight Bookings.csv")

# %%
airlines_df
# Out:
#     airlie_id              airline_name
# 0           1          American Airline
# 1           2           Delta Air Lines
# 2           3           United Airlines
# 3           4        Southwest Airlines
# 4           5           JetBlue Airways
# 5           6           Alaska Airlines
# 6           7           Spirit Airlines
# 7           8         Frontier Airlines
# 8           9         Hawaiian Airlines
# 9          10             Allegiant Air
# 10         11          SkyWest Airlines
# 11         12                Air Canada
# 12         13           British Airways
# 13         14                 Lufthansa
# 14         15                Air France
# 15         16  KLM Royal Dutch Airlines
# 16         17                    Qantas
# 17         18                  Emirates
# 18         19        Singapore Airlines
# 19         20            Cathay Pacific

# %%
columns = flight_bookings_df.columns
len(columns)
# Out:
# 31

# %%
flight_bookings_df[columns[0:10]]
# Out:
#       airlie_id  flght#         departure_dt           arrival_dt  dep_time  \
# 0             6    2637  2023-06-26 00:11:20  2023-10-30 21:30:16  13:48:45
# 1             5    6966  2023-04-27 21:36:15  2023-10-27 13:13:48  14:05:17
# 2            12    5670  2023-03-31 15:08:52  2023-12-30 10:58:37  12:47:06
# 3             1    6203  2023-08-04 16:59:58  2023-03-01 18:34:01  02:46:37
# 4             8    6134  2023-03-07 01:08:36  2023-03-30 04:51:17  13:46:28
# ...         ...     ...                  ...                  ...       ...
# 9995         13    1101  2023-04-14 06:01:22  2023-09-18 13:59:44  20:29:10
# 9996          8    4135  2023-04-30 05:44:58  2023-08-25 14:19:24  10:57:10
# 9997          8    2180  2023-09-20 06:46:41  2023-10-18 17:35:27  14:35:00
# 9998         10    6509  2023-12-16 09:56:10  2023-09-12 12:11:08  22:29:50
# 9999         17    8530  2023-06-13 11:17:19  2023-01-07 03:46:52  02:31:50
#
# ...

# %%
flight_bookings_df[columns[10:20]]
# Out:
#         fare         extras  loyalty_pts     status    gate terminal  \
# 0     436.12           Meal         3649  Cancelled  GateZN        A
# 1     965.80      No Extras         2598    Pending  GateMH        D
# 2     329.94           Meal            0    Pending  GateUU        C
# 3     165.07           Meal            0  Confirmed  GateHX        A
# 4     491.32           Meal            0  Cancelled  GateXU        B
# ...      ...            ...          ...        ...     ...      ...
# 9995  723.91  Extra Baggage            0  Confirmed  GateKB        D
# 9996  889.82      No Extras         4762    Pending  GateIS        D
# 9997  356.92           Meal            0  Confirmed  GateGU        D
# 9998  192.33  Extra Baggage            0  Cancelled  GateFV        B
# 9999  710.14      No Extras            0  Confirmed  GateJL        B
#
#      baggage_claim  duration_hrs  layovers layover_locations
# 0         ClaimJLO          8.06         1            LOCWFQ
# ...

# %%
flight_bookings_df[columns[20:31]]
# Out:
#      aircraft_type       pilot cabin_crew inflight_ent     meal_option  \
# 0          TypeRUH  Pilot_EYZH  Crew_DGAL          Yes  Non-Vegetarian
# 1          TypeSRC  Pilot_OKTY  Crew_VNDX           No      Vegetarian
# 2          TypeLSA  Pilot_UQZR  Crew_PKJB           No           Vegan
# 3          TypePNZ  Pilot_OLHE  Crew_AHUN           No      Vegetarian
# 4          TypeDLG  Pilot_DJHP  Crew_DZUM          Yes  Non-Vegetarian
# ...            ...         ...        ...          ...             ...
# 9995       TypeQVB  Pilot_HUJN  Crew_QVDL           No  Non-Vegetarian
# 9996       TypeOHS  Pilot_SJBM  Crew_BQNX          Yes  Non-Vegetarian
# 9997       TypeSCJ  Pilot_UKGR  Crew_BYGK          Yes      Vegetarian
# 9998       TypeCPS  Pilot_ANEH  Crew_VSUB           No         No Meal
# 9999       TypeTSZ  Pilot_OYNF  Crew_NGHX          Yes         No Meal
#
#                wifi  window_seat  aisle_seat  emergency_exit_row  \
# ...

# %%
flight_bookings_df["flght#"].value_counts()
# Out:
# flght#
# 9353    7
# 7444    7
# 9294    7
# 8749    7
# 9148    6
#        ..
# 1303    1
# 2926    1
# 1856    1
# 6563    1
# 8530    1
# Name: count, Length: 6045, dtype: int64

# %%
# flight_bookings_df[flight_bookings_df["flght#"] == 9353]

# %%
columns
# Out:
# Index(['airlie_id', 'flght#', 'departure_dt', 'arrival_dt', 'dep_time',
#        'arrivl_time', 'booking_cd', 'passngr_nm', 'seat_no', 'class', 'fare',
#        'extras', 'loyalty_pts', 'status', 'gate', 'terminal', 'baggage_claim',
#        'duration_hrs', 'layovers', 'layover_locations', 'aircraft_type',
#        'pilot', 'cabin_crew', 'inflight_ent', 'meal_option', 'wifi',
#        'window_seat', 'aisle_seat', 'emergency_exit_row', 'number_of_stops',
#        'reward_program_member'],
#       dtype='object')

# %%
flight_bookings_df["departure_dt"].value_counts()
# Out:
# departure_dt
# 2023-06-26 00:11:20    1
# 2023-01-21 11:40:12    1
# 2023-05-30 21:19:24    1
# 2023-04-25 04:06:50    1
# 2023-07-18 05:51:35    1
#                       ..
# 2023-06-15 02:16:00    1
# 2023-01-30 10:21:42    1
# 2023-08-08 16:23:17    1
# 2023-12-22 18:12:24    1
# 2023-06-13 11:17:19    1
# Name: count, Length: 10000, dtype: int64
